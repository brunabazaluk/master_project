# %% [markdown]
# ## Pre-processing

# %%
import pandas as pd
data = pd.read_json('cladder.json')
data = data.dropna().reset_index(drop=True)

#create column "formal_form" and "graph" that holds the value corresponding to the key "formal_form" at the dict inside column "meta"

data = data.assign(formal_form = lambda x: (x['meta']))
df = data['formal_form'].apply(lambda x: (x.get("formal_form")))
data['formal_form'] = df

data = data.assign(graph = lambda x: (x['reasoning']))
df = data['graph'].apply(lambda x: (x.get("step1")))
data['graph'] = df
data
# Out:
#       question_id                                            desc_id  \
# 0               4                alarm-mediation-nde-model0-spec0-q0
# 1               7                alarm-mediation-ate-model1-spec1-q1
# 2               8           alarm-mediation-marginal-model1-spec1-q0
# 3              15                alarm-mediation-ate-model3-spec3-q1
# 4              21                alarm-mediation-nie-model4-spec4-q0
# ...           ...                                                ...
# 8527        31012  nonsense9-fork-det-counterfactual-model3842-sp...
# 8528        31014  nonsense9-fork-det-counterfactual-model3842-sp...
# 8529        31015  nonsense9-fork-det-counterfactual-model3842-sp...
# 8530        31016  nonsense9-fork-det-counterfactual-model3843-sp...
# 8531        31019  nonsense9-fork-det-counterfactual-model3843-sp...
#
#                                              given_info  \
# 0     For husbands that don't set the alarm and wive...
# ...

# %%
#exchange "formal_form" and "graph" column's variables to their respective "true name" (ex: exchange X to husband, V2 to wife, etc)
def exchange(x, form, aux):
    x = x.get('step0')
    if(aux):
        form = form.get('formal_form')
    else:
        form = form.get('step1')
    x = x[4:len(x)-1] #erase "Let " and the last "."
    x = x.split('; ')

    for i in range(len(x)):
        aux = x[i].split(" = ")
        form = form.replace(aux[0],aux[1])
    return form

data['final'] = data.apply(lambda x: exchange(x['reasoning'], x['meta'],1), axis=1)
data['final_graph'] = data.apply(lambda x: exchange(x['reasoning'], x['reasoning'],0), axis=1)

data
# Out:
#       question_id                                            desc_id  \
# 0               4                alarm-mediation-nde-model0-spec0-q0
# 1               7                alarm-mediation-ate-model1-spec1-q1
# 2               8           alarm-mediation-marginal-model1-spec1-q0
# 3              15                alarm-mediation-ate-model3-spec3-q1
# 4              21                alarm-mediation-nie-model4-spec4-q0
# ...           ...                                                ...
# 8527        31012  nonsense9-fork-det-counterfactual-model3842-sp...
# 8528        31014  nonsense9-fork-det-counterfactual-model3842-sp...
# 8529        31015  nonsense9-fork-det-counterfactual-model3842-sp...
# 8530        31016  nonsense9-fork-det-counterfactual-model3843-sp...
# 8531        31019  nonsense9-fork-det-counterfactual-model3843-sp...
#
#                                              given_info  \
# 0     For husbands that don't set the alarm and wive...
# ...

# %%
len(data)
# Out:
# 8532

# %%
#create dataframe df to store the text (given_info + question) and respective formal form
df_form = data[['final']].copy()
df_form['text'] = data.apply(lambda x: (x['given_info'] + x['question']), axis=1)
#df = df.rename(columns={'final': 'label'})
df_form = df_form[['text','final']]

#separate 10% of the dataset to make final tests (don't use as validation during training)
p = len(data)//10
final_test_form = df_form.iloc[:p]
df_form = df_form.iloc[p:].reset_index(drop=True)

df_form
# Out:
#                                                    text  \
# 0     The overall probability of increased supply is...
# 1     The overall probability of increased supply is...
# 2     For farms with reduced crop yield per acre, th...
# 3     The overall probability of increased supply is...
# 4     The overall probability of increased supply is...
# ...                                                 ...
# 7674  We know that zuph or jyka causes glimx. We obs...
# 7675  We know that zuph or jyka causes glimx. We obs...
# 7676  We know that zuph or jyka causes glimx. We obs...
# 7677  We know that zuph and jyka causes glimx. We ob...
# 7678  We know that zuph and jyka causes glimx. We ob...
#
#                                                   final
# 0                                              P(price)
# 1                                     P(price | supply)
# 2     E[price | do(supply = 1)] - E[price | do(suppl...
# 3                                              P(price)
# ...

# %%
#create dataframe df to store the text (given_info + question) and respective graph
df_graph = data[['final_graph']].copy()
df_graph['text'] = data.apply(lambda x: (x['given_info'] + x['question']), axis=1)
#df = df.rename(columns={'final': 'label'})
df_graph = df_graph[['text','final_graph']]

#separate 10% of the dataset to make final tests (don't use as validation during training)
p = len(data)//10
final_test_graph = df_graph.iloc[:p]
df_graph = df_graph.iloc[p:].reset_index(drop=True)

df_graph
# Out:
#                                                    text  \
# 0     The overall probability of increased supply is...
# 1     The overall probability of increased supply is...
# 2     For farms with reduced crop yield per acre, th...
# 3     The overall probability of increased supply is...
# 4     The overall probability of increased supply is...
# ...                                                 ...
# 7674  We know that zuph or jyka causes glimx. We obs...
# 7675  We know that zuph or jyka causes glimx. We obs...
# 7676  We know that zuph or jyka causes glimx. We obs...
# 7677  We know that zuph and jyka causes glimx. We ob...
# 7678  We know that zuph and jyka causes glimx. We ob...
#
#                                             final_graph
# 0     demand->supply,yield per acre->supply,demand->...
# 1     demand->supply,yield per acre->supply,demand->...
# 2     demand->supply,yield per acre->supply,demand->...
# 3     demand->supply,yield per acre->supply,demand->...
# ...

# %%
#Transform dataset from DataFrame to Dataset
import datasets
from datasets import Dataset, DatasetDict

df_form = df_form.sample(frac=1).reset_index(drop=True)
dataset = Dataset.from_pandas(df_form)
split_form = dataset.train_test_split(train_size=0.9, seed=20)

split_form
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'final'],
#         num_rows: 6911
#     })
#     test: Dataset({
#         features: ['text', 'final'],
#         num_rows: 768
#     })
# })

# %%
#Transform dataset from DataFrame to Dataset
import datasets
from datasets import Dataset, DatasetDict

df_graph = df_graph.sample(frac=1).reset_index(drop=True)
dataset = Dataset.from_pandas(df_graph)
split_graph = dataset.train_test_split(train_size=0.9, seed=20)

split_graph
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'final_graph'],
#         num_rows: 6911
#     })
#     test: Dataset({
#         features: ['text', 'final_graph'],
#         num_rows: 768
#     })
# })

# %% [markdown]
# ## Fine-tuning t5-small to translate the texts to the "formal form"
#
# The following code was written based on:
# https://github.com/adam5644/Quantitative_Trading_and_Research/blob/master/T5-Small%20Summarizer%2C%20Transformer%20seq2seq%2C%20Transfer-Learning.ipynb

# %%
from transformers import AutoTokenizer
# (Q) What is the "transformers" library
# transformers is a widely-used library that provides a range of
# pre-trained models for Natural Language Processing (NLP) tasks such
# as text classification, translation, summarization

# (Q) What is AutoTokenizer
# A tokenizer is responsible for converting raw text into a format that
# is understandable by the model. This includes splitting the text into
# tokens (like words or subwords), converting tokens to their respective
# IDs in a pre-defined vocabulary, and applying other text preprocessing
# steps like padding and truncation.

tokenizer = AutoTokenizer.from_pretrained("t5-small")
# Out:
# /home/bazaluk/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
prefix = "translate: " # tell machine that we want to "translate" every input data

def preprocess_function(examples):
    inputs = [prefix + doc for doc in examples["text"]]
    model_inputs = tokenizer(inputs, max_length=1024, truncation=True) # max text length is 1024
    labels = tokenizer(text=examples["final"], max_length=256, truncation=True) # max len of form is 256
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenized_dataset_form = split_form.map(preprocess_function, batched=True)

# (Q) .map(function,)
# apply "preprocess_function" to every single element (or batch of element)

# (Q) "batched=True"?
# indicates that the preprocess_function should be applied to the dataset in batches rather than individual examples. Processing data in batches is typically more efficient, especially when dealing with large datasets.
# Out:
# ...
# Map:   0%|          | 0/768 [00:00<?, ? examples/s]

# %%
from transformers import DataCollatorForSeq2Seq, AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer

data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model='t5-small')
# model='t5-small' --> indicates that the collator should prepare data suitable for the 't5-small' model
# data_collator --> makes the training and testing sets into appropriately-sized tensors

model_form = AutoModelForSeq2SeqLM.from_pretrained("t5-small")
# This method downloads and caches the 't5-small' model, a smaller
# variant of the T5 model optimized for Seq2Seq tasks. If the model is
# already downloaded, it is loaded from the cache.

# %%
training_args = Seq2SeqTrainingArguments(
  output_dir="./results_form", # where model checkpoints will be saved
  evaluation_strategy="epoch", # evaluate model (and save checkpoint) at end of each training epoch
  learning_rate=2e-5, # learning rate for the optimizer. A learning rate of 2e-5 (or 0.00002) is a common choice for fine-tuning models in NLP tasks.
  per_device_train_batch_size=10, # 10 examples will be processed simultaneously during training on each device (i.e. gpu or cpu)
  per_device_eval_batch_size=10, # 10 examples will be processed simultaneously during evaluation on each device  (i.e. gpu or cpu)
  weight_decay=0.01, # regularization parameter that helps prevent overfitting. It adds an additional term to the cost function related to the size of the model weights, which encourages smaller weights
  save_total_limit=3, # 3 checkpoints
  num_train_epochs=10, # Sets the number of epochs for training. An epoch is one complete pass through the entire training dataset.
  fp16=True, # use 16-bit floating values (as opposed to default 32-bit) which can reduce memory usage and potentially increase training speed, especially on GPUs that support it.
  )

# %%
trainer = Seq2SeqTrainer(
  model=model_form,
  args=training_args,
  train_dataset=tokenized_dataset_form["train"],
  eval_dataset=tokenized_dataset_form["test"],
  tokenizer=tokenizer,
  data_collator=data_collator,
  )

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='6920' max='6920' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6920/6920 09:29, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.660300</td>
#       <td>0.246848</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.474000</td>
#       <td>0.108345</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.178100</td>
#       <td>0.061827</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.128200</td>
#       <td>0.042167</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.104200</td>
#       <td>0.032241</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.070300</td>
#       <td>0.027787</td>
#     </tr>
#     <tr>
#       <td>7</td>
# ...

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='77' max='77' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [77/77 00:01]
#     </div>
# {'eval_loss': 0.02283748798072338,
#  'eval_runtime': 1.7681,
#  'eval_samples_per_second': 434.356,
#  'eval_steps_per_second': 43.549,
#  'epoch': 10.0}

# %%
import shutil
import os

### save 'results' folder which contain checkpoints as zip
# shutil.make_archive('/content/results', 'zip', '/content/results') #first path is the name of zip folder, second path is the input folder to be converted to zip


trainer.save_model("trained_model_form")
#### save trained_model as zip
#shutil.make_archive('trained_model', 'zip', 'trained_model')
# shutil.make_archive('/content/trained_model', 'zip', '/content/trained_model') #first path is the name of zip folder, second path is the input folder to be converted to zip

# %% [markdown]
# ## Testing with final_test

# %%
def predict_summary_form(document):
  device = model_form.device
  tokenized = tokenizer([document], truncation =True, padding ='longest',return_tensors='pt')
  tokenized = {k: v.to(device) for k, v in tokenized.items()}
  tokenized_result = model_form.generate(**tokenized, max_length=128)
  tokenized_result = tokenized_result.to('cpu')
  predicted_summary = tokenizer.decode(tokenized_result[0])
  return predicted_summary

# %%
pd.set_option('display.max_colwidth', None)
final_test_form.iloc[900]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[77], line 2
#       1 pd.set_option('display.max_colwidth', None)
# ----> 2 final_test_form.iloc[900]
#
# File ~/lib/python3.10/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/lib/python3.10/site-packages/pandas/core/indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# ...

# %%
teste = predict_summary_form(final_test_form.iloc[100]['text'])
teste


def translate(final_test_form):
    translated_df = final_test_form.copy()

    translated_df['translation'] = ""

    for i in range(len(translated_df)):
        translated_df['translation'].iloc[i] = clean_translation(predict_summary_form(final_test_form.iloc[i]['text']))
    
    return translated_df

def save_csv(df):
    df.to_csv('/media/data/bazaluk/t5_form.csv')

# %%
save_csv(translate(final_test_form))
# Out:
# /tmp/ipykernel_1691902/167983328.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   translated_df['translation'].iloc[i] = clean_translation(predict_summary_form(final_test_form.iloc[i]['text']))
# ...

# %%
csv_form = pd.read_csv("/media/data/bazaluk/t5_form.csv")
csv_form
# Out:
#      Unnamed: 0  \
# 0             0
# 1             1
# 2             2
# 3             3
# 4             4
# ..          ...
# 848         848
# 849         849
# 850         850
# 851         851
# 852         852
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     text  \
# ...

# %%
def clean_translation(trans):
    return trans[6:-4]
clean_translation(csv_form['translation'].iloc[0])
# Out:
# 'E[alarm clock_<unk>husband=1, wife=0<unk> - alarm clock_<unk>husband=0, wife=0<unk>]'

# %%
#in order to test accuracy, we substitute <unk> with { or } and ignore the spaces between words

def clean_translation(form):
    #exclude "<pad> "
    form = form[6:-4]
    if ('_' in form): #there are curly braces we need to add
        form_list = form.split('<unk>')
        i = 0
        stack = 0
        while i in range(len(form_list)):
            #assuming all forms are written correctly (none ends with '_') and the only <unk> characters represent curly braces:
            if (form_list[i][-1] == '_'):
                form_list.insert(i+1, '{')
                i += 2
                stack += 1
            elif (stack > 0):
                form_list.insert(i+1, '}')
                stack -= 1
                i += 1
            else:
                i += 1
        aux = ""
        return aux.join(form_list).replace(' ','')
    return form.replace(' ','')

# %%
clean_translation(teste)
# Out:
# 'E[employee_{manager=1}-employee_{manager=0}|manager=1]'

# %%
def acc_form(final):
    acc = 0
    for i in range(len(final)):
        translation = clean_translation(predict_summary_form(final_test_form.iloc[i]['text']))
        ground_truth = final_test_form.iloc[i]['final'].replace(' ','')
        if (translation == ground_truth):
            acc += 1
        else:
            print('ground truth: ', ground_truth)
            print('\n')
            print('translation: ', translation)
            print('---------\n')
    return acc/len(final)

def translate(final):

# %%
acc_form(final_test_form)
# Out:
# ground truth:  P(alarmclock)
#
#
# translation:  E[alarmclock_{husband=0,husband=0}-alarmclock_{husband=0,husband=0}]
# ---------
#
# ground truth:  P(alarmclock)
#
#
# translation:  E[alarmclock_{husband=0,husband=0}-alarmclock_{husband=0,husband=0}]
# ---------
#
# ground truth:  P(alarmclock)
#
#
# translation:  E[alarmclock_{husband=0,husband=0}-alarmclock_{husband=0,husband=0}]
# ---------
#
# ground truth:  P(alarmclock)
#
#
# translation:  E[alarmclock_{husband=0,husband=0}-alarmclock_{husband=0,husband=0}]
# ---------
#
# ground truth:  P(alarmclock)
#
#
# translation:  E[alarmclock_{husband=0,husband=0}-alarmclock_{husband=0,husband=0}]
# ---------
#
# ground truth:  P(alarmclock)
#
#
# translation:  E[alarmclock_{husband=0,husband=0}-alarmclock_{husband=0,husband=0}]
# ---------
#
# ground truth:  P(room|themanintheroom)
#
#
# translation:  P(room|theabilitytoblowoutthecandle)
# ---------
#
# ground truth:  E[room|do(themanintheroom=1)]-E[room|do(themanintheroom=0)]
#
#
# ...

# %%
#data=data.dropna()
data_cp = csv_form.copy()
lista1 = list(data_cp['translation'].unique())
lista2 = list(data_cp["final"].unique())
#np.append(lista,'normal counterfactual question')
lista = lista1+lista2

dicio = dict(zip(lista,range(10000)))

data_cp["translation"].replace(dicio)
data_cp["final"].replace(dicio)
# Out:
# /tmp/ipykernel_1691902/2912677105.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_cp["translation"].replace(dicio)
# /tmp/ipykernel_1691902/2912677105.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_cp["final"].replace(dicio)
# 0      146
# 1      147
# 2      148
# 3      147
# 4      149
#       ...
# 848    259
# 849    260
# 850    259
# 851    258
# 852    259
# Name: final, Length: 853, dtype: int64

# %%
from sklearn.metrics import f1_score
f1_score(data_cp["final"], data_cp["translation"], average='weighted')
# Out:
# 0.4135977738556871

# %% [markdown]
# ## Fine-tuning t5-small to translate the texts to the causal graph

# %%
from transformers import AutoTokenizer
# (Q) What is the "transformers" library
# transformers is a widely-used library that provides a range of
# pre-trained models for Natural Language Processing (NLP) tasks such
# as text classification, translation, summarization

# (Q) What is AutoTokenizer
# A tokenizer is responsible for converting raw text into a format that
# is understandable by the model. This includes splitting the text into
# tokens (like words or subwords), converting tokens to their respective
# IDs in a pre-defined vocabulary, and applying other text preprocessing
# steps like padding and truncation.

tokenizer = AutoTokenizer.from_pretrained("t5-small")
# Out:
# /home/bazaluk/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
prefix = "translate: " # tell machine that we want to "translate" every input data

def preprocess_function(examples):
    inputs = [prefix + doc for doc in examples["text"]]
    model_inputs = tokenizer(inputs, max_length=1024, truncation=True) # max text length is 1024
    labels = tokenizer(text=examples["final_graph"], max_length=256, truncation=True) # max len of form is 256
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenized_dataset_graph = split_graph.map(preprocess_function, batched=True)

# (Q) .map(function,)
# apply "preprocess_function" to every single element (or batch of element)

# (Q) "batched=True"?
# indicates that the preprocess_function should be applied to the dataset in batches rather than individual examples. Processing data in batches is typically more efficient, especially when dealing with large datasets.
# Out:
# ...
# Map:   0%|          | 0/768 [00:00<?, ? examples/s]

# %%
from transformers import DataCollatorForSeq2Seq, AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer

data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model='t5-small')
# model='t5-small' --> indicates that the collator should prepare data suitable for the 't5-small' model
# data_collator --> makes the training and testing sets into appropriately-sized tensors

model_graph = AutoModelForSeq2SeqLM.from_pretrained("t5-small")
# This method downloads and caches the 't5-small' model, a smaller
# variant of the T5 model optimized for Seq2Seq tasks. If the model is
# already downloaded, it is loaded from the cache.
# Out:
# /home/bazaluk/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
training_args = Seq2SeqTrainingArguments(
  output_dir="/media/data/bazaluk/results_graphs", # where model checkpoints will be saved
  evaluation_strategy="epoch", # evaluate model (and save checkpoint) at end of each training epoch
  learning_rate=2e-5, # learning rate for the optimizer. A learning rate of 2e-5 (or 0.00002) is a common choice for fine-tuning models in NLP tasks.
  per_device_train_batch_size=10, # 10 examples will be processed simultaneously during training on each device (i.e. gpu or cpu)
  per_device_eval_batch_size=10, # 10 examples will be processed simultaneously during evaluation on each device  (i.e. gpu or cpu)
  weight_decay=0.01, # regularization parameter that helps prevent overfitting. It adds an additional term to the cost function related to the size of the model weights, which encourages smaller weights
  save_total_limit=3, # 3 checkpoints
  num_train_epochs=10, # Sets the number of epochs for training. An epoch is one complete pass through the entire training dataset.
  fp16=True, # use 16-bit floating values (as opposed to default 32-bit) which can reduce memory usage and potentially increase training speed, especially on GPUs that support it.
  )

# %%
trainer = Seq2SeqTrainer(
  model=model_graph,
  args=training_args,
  train_dataset=tokenized_dataset_graph["train"],
  eval_dataset=tokenized_dataset_graph["test"],
  tokenizer=tokenizer,
  data_collator=data_collator,
  )

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='6920' max='6920' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6920/6920 10:23, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.940300</td>
#       <td>0.678704</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.914400</td>
#       <td>0.384602</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.501400</td>
#       <td>0.259021</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.406200</td>
#       <td>0.189322</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.348300</td>
#       <td>0.147471</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.261000</td>
#       <td>0.119520</td>
#     </tr>
#     <tr>
#       <td>7</td>
# ...

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='77' max='77' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [77/77 00:01]
#     </div>
# {'eval_loss': 0.08638826757669449,
#  'eval_runtime': 1.7318,
#  'eval_samples_per_second': 443.47,
#  'eval_steps_per_second': 44.463,
#  'epoch': 10.0}

# %%
import shutil
import os

### save 'results' folder which contain checkpoints as zip
# shutil.make_archive('/content/results', 'zip', '/content/results') #first path is the name of zip folder, second path is the input folder to be converted to zip


trainer.save_model("trained_model_graph")
#### save trained_model as zip
#shutil.make_archive('trained_model', 'zip', 'trained_model')
# shutil.make_archive('/content/trained_model', 'zip', '/content/trained_model') #first path is the name of zip folder, second path is the input folder to be converted to zip

# %% [markdown]
# ## Testing with final test

# %%
def predict_summary_graph(document):
  device = model_graph.device
  tokenized = tokenizer([document], truncation =True, padding ='longest',return_tensors='pt')
  tokenized = {k: v.to(device) for k, v in tokenized.items()}
  tokenized_result = model_graph.generate(**tokenized, max_length=128)
  tokenized_result = tokenized_result.to('cpu')
  predicted_summary = tokenizer.decode(tokenized_result[0])
  return predicted_summary

# %%
pd.set_option('display.max_colwidth', None)
final_test_graph.iloc[100]
# Out:
# text           For managers who don't sign termination letters and directors who don't sign termination letters, the probability of employee being fired is 9%. For managers who don't sign termination letters and directors who sign termination letters, the probability of employee being fired is 47%. For managers who sign termination letters and directors who don't sign termination letters, the probability of employee being fired is 50%. For managers who sign termination letters and directors who sign termination letters, the probability of employee being fired is 85%. For managers who don't sign termination letters, the probability of director signing the termination letter is 66%. For managers who sign termination letters, the probability of director signing the termination letter is 73%.For managers who sign termination letters, would it be more likely to see employee being fired if the manager had signed the termination letter?
# ...

# %%
teste = predict_summary_graph(final_test_graph.iloc[300]['text'])
teste

def translate(final_test_graph):
    translated_df = final_test_graph.copy()

    translated_df['translation'] = ""

    for i in range(len(translated_df)):
        translated_df['translation'].iloc[i] = predict_summary_graph(final_test_graph.iloc[i]['text'])
    
    return translated_df

def save_csv(df):
    df.to_csv('/media/data/bazaluk/t5_graph.csv')

# %%
save_csv(translate(final_test_graph))
# Out:
# /tmp/ipykernel_1691902/118018484.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   translated_df['translation'].iloc[i] = predict_summary_graph(final_test_graph.iloc[i]['text'])
# ...

# %%
csv_graph = pd.read_csv("/media/data/bazaluk/t5_graph.csv")
csv_graph
# Out:
#      Unnamed: 0  \
# 0             0
# 1             1
# 2             2
# 3             3
# 4             4
# ..          ...
# 848         848
# 849         849
# 850         850
# 851         851
# 852         852
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     text  \
# ...

# %%
final_test_graph.iloc[300]['final_graph']
# Out:
# 'my decision->penguin mood,my decision->penguin survival,penguin mood->penguin survival'

# %%
clean_translation(teste)
# Out:
# 'CEO->director,CEO->manager,manager->employee'

# %%
def get_graph(text):
    for i in range(len(text)):
        if text[i] == ':':
            break

    text = text[i+1:]

    return text.replace(' ','').replace('\n','').replace('.','').replace('\\n','')

def clean_translation(trans):
    return trans[6:-4]

# %%
def acc_graph(final):
    acc = 0
    for i in range(len(final)):
        translation = clean_translation(predict_summary_graph(final_test_graph.iloc[i]['text']))
        ground_truth = final_test_graph.iloc[i]['final_graph'].replace(' ','')
        if (translation == ground_truth):
            acc += 1
        else:
            print('ground truth: ', ground_truth)
            print('\n')
            print('translation: ', translation)
            print('---------\n')
    return acc/len(final)

def acc_graph2(final):
    acc = 0
    for i in range(len(final)):
        if type(final_test_graph.iloc[i]['final_graph']) == str:
            #print(i)
            pred = clean_translation(predict_summary_graph(final_test_graph.iloc[i]['text'])).split(',')
            true_graph = final_test_graph.iloc[i]['final_graph'].split(',')

            #print(pred,true_graph)
            if set(pred) == set(true_graph):
                acc += 1
            #print(pred,true_graph)
    return acc/len(final)

# %%
acc_graph2(final_test_graph)
# Out:
# 0.37631887456037516

# %%
edgelist = [(0, 1)]  # single edge (0,1)

G = nx.from_edgelist(edgelist)

# %%
import re
def make_edgelist(pred_graph, true_graph):
    d_split = list(set(re.split(r',|->', pred_graph+','+true_graph)))
    dicio = dict(zip(d_split,range(100)))

    pred_graph = pred_graph.split(',')

    for i in range(len(pred_graph)):
        pred_graph[i] = pred_graph[i].split('->')

    pred_graph = list(map(tuple, pred_graph))
    pred_graph = [tup for tup in pred_graph if len(tup) == 2]
    
    true_graph = true_graph.split(',')

    for i in range(len(true_graph)):
        true_graph[i] = true_graph[i].split('->')
    true_graph = list(map(tuple, true_graph))
    true_graph = [tup for tup in true_graph if len(tup) == 2]

    
    return pred_graph, true_graph

import networkx as nx

def graph_ed(p_graph, t_graph):
    pred_graph, true_graph = make_edgelist(p_graph, t_graph)

    G_pred = nx.from_edgelist(pred_graph)
    G_true = nx.from_edgelist(true_graph)

    return nx.graph_edit_distance(G_pred, G_true)

def ged_mean(final):
    mean = 0
    for i in range(len(final)):
        pred_graph = clean_translation(final['translation'].iloc[i])
        true_graph = final.iloc[i]['final_graph']

        mean += graph_ed(pred_graph, true_graph)
    
    return mean/len(final)

# %%
ged_mean(csv_graph)
#p_graph = clean_translation(predict_summary_graph(final_test_graph.iloc[300]['text']))
#t_graph = final_test_graph.iloc[300]['final_graph']

#graph_ed(p_graph, t_graph)
# Out:
# 1.3376318874560376

# %%
a=['a','b','c']
a.pop(0)
a
pred_graph = 'CEO->director,CEO->manager,manager->employee'
true_graph = 'CEO->director,CEO->manager,manager'
a,b=make_edgelist(pred_graph, true_graph)

# %%
c=[tup for tup in b if len(tup) == 2]
b,c
# Out:
# ([('CEO', 'director'), ('CEO', 'manager'), ('manager',)],
#  [('CEO', 'director'), ('CEO', 'manager')])
